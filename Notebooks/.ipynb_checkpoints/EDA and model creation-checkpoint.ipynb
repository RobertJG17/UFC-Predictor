# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
master = pd.read_csv('../Training Data/ufc-master.csv')

# %%
# TAKE THE DATE OF THE FIRST ENTRY AND EXCLUDE ALL ENTRIES WITH THAT DATE (EXCLUDES MOST RECENT EVENT)

master = master.loc[master.date != master.iloc[0]['date'], :].reset_index().drop("index", axis=1)

# %%
master.head(3)
# Out:
#         R_fighter      B_fighter  R_odds  B_odds        R_ev       B_ev  \
# 0   Derrick Lewis     Ciryl Gane     250    -320  250.000000  31.250000
# 1       Jose Aldo   Pedro Munhoz    -105    -115   95.238095  86.956522
# 2  Michael Chiesa  Vicente Luque    -115    -105   86.956522  95.238095
#
#        date             location country Winner  ...  finish_details  \
# 0  8/7/2021  Houston, Texas, USA     USA   Blue  ...         Punches
# 1  8/7/2021  Houston, Texas, USA     USA    Red  ...             NaN
# 2  8/7/2021  Houston, Texas, USA     USA   Blue  ...    D'Arce Choke
#
#   finish_round finish_round_time  total_fight_time_secs  r_dec_odds  \
# 0          3.0              4:11                  851.0      1400.0
# 1          3.0              5:00                  900.0       150.0
# 2          1.0              3:25                  205.0       225.0
#
#    b_dec_odds  r_sub_odds  b_sub_odds  r_ko_odds  b_ko_odds
# 0       215.0      2200.0       600.0      330.0      120.0
# ...

# %%
plt.figure(figsize=(16,8), dpi=200)
sns.countplot(data=master, x="Winner");

# %%
# NUM OF ROWS IN THE DATASET

len(master)
# Out:
# 4826

# %%
# WINNER -> {"Red": 1, "Blue": 0}

master["Winner Dummies"] = master.Winner.map({"Red": 1, "Blue": 0})

# %%
# TOP 20 FEATURES THAT ARE MOST HIGHLY CORRELATED WITH WINNING (BY ABSOLUATE VAL)

pearson_corr = abs(master.corr()["Winner Dummies"]).sort_values(ascending=False)

# %%
plt.figure(figsize=(16,8), dpi=200)

sns.barplot(y=pearson_corr.index[1:21], x=pearson_corr.values[1:21], orient='h')
plt.title("Feature Correlations to Winning by Pearson Ranking")

fig.tight_layout()

# %%
# WE WILL CONSIDER THE HIGHEST CORRELATED FEATURES THAT ARE NOT UNIQUE TO WEIGHTCLASSES OR GENDERS

features = pearson_corr.loc[
    [
        "B_odds", "R_odds", 
        "B_ev", "R_ev", 
        "b_dec_odds", "r_dec_odds",
        "b_ko_odds", "r_ko_odds", 
        "b_sub_odds", "r_sub_odds",
    ]
]

# %%
nan_ser = master.loc[:, features.index].isnull().sum() / len(master)

nan_ser.sort_values()
# Out:
# B_odds        0.000000
# R_odds        0.000000
# B_ev          0.000000
# R_ev          0.000000
# r_dec_odds    0.166183
# b_dec_odds    0.169499
# r_ko_odds     0.217157
# r_sub_odds    0.217157
# b_sub_odds    0.219644
# b_ko_odds     0.219851
# dtype: float64

# %%
X = master.dropna(subset=nan_ser.sort_values().index, axis=0).loc[:, features.index]

# %%
# NUM OF ROWS IN CLEANED DATAFRAME WITH SELECTED FEATURES

len(X)
# Out:
# 3694

# %%
y = master.dropna(subset=nan_ser.sort_values().index, axis=0).loc[:, "Winner"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=17)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier

# %%
# CREATE RANDOM FOREST CLASSIFIER MODEL

rfc = RandomForestClassifier()

# %%
# FOR SVC MODEL

# param_grid = {
#     "C": np.arange(0.1, 1.1, 0.1),
#     "kernel": ['rbf', 'poly', 'sigmoid'],
#     "class_weight": ["balanced"]
# }

# FOR RFC ENSEMBLE MODEL

param_grid = {
    "max_depth": [10, 12, 14, 16],
    "n_estimators": [100, 110, 120, 130],
    "class_weight": ["balanced", "balanced_subsample"]
}

# %%
# USE GRIDSEARCH TO FIND OPTIMAL HYPERPARAMETERS

grid = GridSearchCV(estimator=rfc, param_grid=param_grid)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'max_depth': [10, 12, 14, 16],
#                          'n_estimators': [100, 110, 120, 130]})

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10)

# %%
model = grid.best_estimator_

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10)

# %%
# GRAB FEATURE IMPORTANCES FROM OUR ADABOOSTER AND USE A LINECHART TO VISUALIZE THEM

feat_imp = model.feature_importances_
feature_labels = X.columns
feat_ser = pd.Series(data=feat_imp, index=feature_labels).sort_values()

# %%
import plotly.express as px

# %%
px.line(x=feat_ser.index, y=feat_ser.values, title="Feature vs. Feature Importance")
# Out:
# <div>                            <div id="951f5c5b-9b72-40fc-8822-d7b89f5ceeb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("951f5c5b-9b72-40fc-8822-d7b89f5ceeb9")) {                    Plotly.newPlot(                        "951f5c5b-9b72-40fc-8822-d7b89f5ceeb9",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["r_sub_odds", "r_ko_odds", "b_ko_odds", "b_sub_odds", "r_dec_odds", "B_ev", "R_odds", "b_dec_odds", "B_odds", "R_ev"], "xaxis": "x", "y": [0.08723776795254437, 0.09292729494378438, 0.09683755555065097, 0.09685200310409102, 0.0976967115123413, 0.09934888
# ...

# %%
predictions = model.predict(X_val)

# %%
probabilities = model.predict_proba(X_val)

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
fig, ax = plt.subplots(figsize=(10, 5), dpi=200)
plot_confusion_matrix(model, X_val, y_val, ax=ax)

# %%
print(classification_report(y_val, predictions))
# Out:
#               precision    recall  f1-score   support
#
#         Blue       0.60      0.62      0.61       239
#          Red       0.70      0.69      0.70       316
#
#     accuracy                           0.66       555
#    macro avg       0.65      0.65      0.65       555
# weighted avg       0.66      0.66      0.66       555

# %%
# DUMP MODEL TO BE USED FOR TEST SET
from joblib import dump

# %%
# final_scaler = StandardScaler()
# final_scaler.fit_transform(X)
# dump(final_scaler, '../Model and Scaler/final_scaler.joblib')

# %%
final_rfc = grid.best_estimator_
final_rfc.fit(X, y)
dump(final_rfc, '../Model and Scaler/final_rfc.joblib')
# Out:
# ['../Model and Scaler/final_rfc.joblib']
